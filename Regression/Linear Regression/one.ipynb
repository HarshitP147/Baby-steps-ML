# %%
import pandas as pd

# insurance.csv is the original file from which the data is read
medical_ins_df = pd.read_csv('./medical.csv')
medical_ins_df.info()         # we get the datatype of each of the column
medical_ins_df.describe()     # we get numerical analysis of the
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         1338 non-null   int64
#  1   sex         1338 non-null   object
#  2   bmi         1338 non-null   float64
#  3   children    1338 non-null   int64
#  4   smoker      1338 non-null   object
#  5   region      1338 non-null   object
#  6   charges     1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB
#               age       bmi        children        charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# importing required libraries for plotting
import matplotlib
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib inline


# setting basic graph colors and properties
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (10,6)
matplotlib.rcParams['figure.facecolor'] = '#000000'

# %%
# # giving the complete analysis of a column in the dataset along with it's graph

# age_fig = px.histogram(medical_ins_df,x='age',marginal='box',nbins=47,title='Distribution of age')
# age_fig.update_layout(bargap=0.1)
# age_fig.show()

# medical_ins_df.age.describe()

# %%
bmi_fig = px.histogram(medical_ins_df,x='bmi',marginal='box',color_discrete_sequence=['red'],title='Distribution of BMI')
bmi_fig.update_layout(bargap=0.1)
bmi_fig.show()

medical_ins_df.bmi.describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 bmi_fig = px.histogram(medical_ins_df,x='bmi',marginal='box',color_discrete_sequence=['red'],title='Distribution of BMI')
#       2 bmi_fig.update_layout(bargap=0.1)
#       3 bmi_fig.show()
#
# File c:\Users\Harshit Pandit\Desktop\Machine-Learning\.venv\Lib\site-packages\plotly\express\_chart_types.py:480, in histogram(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, pattern_shape_sequence, pattern_shape_map, marginal, opacity, orientation, barmode, barnorm, histnorm, log_x, log_y, range_x, range_y, histfunc, cumulative, nbins, text_auto, title, template, width, height)
#     434 def histogram(
#     435     data_frame=None,
#     436     x=None,
#    (...)
#     472     height=None,
#     473 ) -> go.Figure:
#     474     """
#     475     In a histogram, rows of `data_frame` are grouped together into a
#     476     rectangular mark to visualize the 1D distribution of an aggregate
#     477     function `histfunc` (e.g. the count or sum) of the value `y` (or `x` if
#     478     `orientation` is `'h'`).
#     479     """
# --> 480     return make_figure(
#     481         args=locals(),
#     482         constructor=go.Histogram,
#     483         trace_patch=dict(
#     484             histnorm=histnorm,
#     485             histfunc=histfunc,
#     486             cumulative=dict(enabled=cumulative),
#     487         ),
#     488         layout_patch=dict(barmode=barmode, barnorm=barnorm),
#     489     )
#
# File c:\Users\Harshit Pandit\Desktop\Machine-Learning\.venv\Lib\site-packages\plotly\express\_core.py:2076, in make_figure(args, constructor, trace_patch, layout_patch)
#    2073 layout_patch = layout_patch or {}
#    2074 apply_default_cascade(args)
# -> 2076 args = build_dataframe(args, constructor)
#    2077 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2078     args = process_dataframe_hierarchy(args)
#
# File c:\Users\Harshit Pandit\Desktop\Machine-Learning\.venv\Lib\site-packages\plotly\express\_core.py:1485, in build_dataframe(args, constructor)
#    1482     args["color"] = None
#    1483 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1485 df_output, wide_id_vars = process_args_into_dataframe(
#    1486     args, wide_mode, var_name, value_name
#    1487 )
#    1489 # now that `df_output` exists and `args` contains only references, we complete
#    1490 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1491 # df_output
#    1493 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File c:\Users\Harshit Pandit\Desktop\Machine-Learning\.venv\Lib\site-packages\plotly\express\_core.py:1210, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1208         if argument == "index":
#    1209             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1210         raise ValueError(err_msg)
#    1211 elif length and len(df_input[argument]) != length:
#    1212     raise ValueError(
#    1213         "All arguments should have the same length. "
#    1214         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1221         )
#    1222     )
#
# ValueError: Value of 'x' is not the name of a column in 'data_frame'. Expected one of ['age ', 'sex    ', 'bmi    ', 'children ', 'smoker ', 'region    ', 'charges'] but received: bmi

# %%
# nbins for children = 6
children_fig = px.histogram(medical_ins_df,x='children',marginal='box',color_discrete_sequence=['green'],nbins=6,title='Number of children')
children_fig.update_layout(bargap=0.1)
children_fig.show()

medical_ins_df.children.describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 # nbins for children = 6
# ----> 2 children_fig = px.histogram(medical_ins_df,x='children',marginal='box',color_discrete_sequence=['green'],nbins=6,title='Number of children')
#       3 children_fig.update_layout(bargap=0.1)
#       4 children_fig.show()
#
# File c:\Users\Harshit Pandit\Desktop\Machine-Learning\.venv\Lib\site-packages\plotly\express\_chart_types.py:480, in histogram(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, pattern_shape_sequence, pattern_shape_map, marginal, opacity, orientation, barmode, barnorm, histnorm, log_x, log_y, range_x, range_y, histfunc, cumulative, nbins, text_auto, title, template, width, height)
#     434 def histogram(
#     435     data_frame=None,
#     436     x=None,
#    (...)
#     472     height=None,
#     473 ) -> go.Figure:
#     474     """
#     475     In a histogram, rows of `data_frame` are grouped together into a
#     476     rectangular mark to visualize the 1D distribution of an aggregate
#     477     function `histfunc` (e.g. the count or sum) of the value `y` (or `x` if
#     478     `orientation` is `'h'`).
#     479     """
# --> 480     return make_figure(
#     481         args=locals(),
#     482         constructor=go.Histogram,
#     483         trace_patch=dict(
#     484             histnorm=histnorm,
#     485             histfunc=histfunc,
#     486             cumulative=dict(enabled=cumulative),
#     487         ),
#     488         layout_patch=dict(barmode=barmode, barnorm=barnorm),
#     489     )
#
# File c:\Users\Harshit Pandit\Desktop\Machine-Learning\.venv\Lib\site-packages\plotly\express\_core.py:2076, in make_figure(args, constructor, trace_patch, layout_patch)
#    2073 layout_patch = layout_patch or {}
#    2074 apply_default_cascade(args)
# -> 2076 args = build_dataframe(args, constructor)
#    2077 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2078     args = process_dataframe_hierarchy(args)
#
# File c:\Users\Harshit Pandit\Desktop\Machine-Learning\.venv\Lib\site-packages\plotly\express\_core.py:1485, in build_dataframe(args, constructor)
#    1482     args["color"] = None
#    1483 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1485 df_output, wide_id_vars = process_args_into_dataframe(
#    1486     args, wide_mode, var_name, value_name
#    1487 )
#    1489 # now that `df_output` exists and `args` contains only references, we complete
#    1490 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1491 # df_output
#    1493 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File c:\Users\Harshit Pandit\Desktop\Machine-Learning\.venv\Lib\site-packages\plotly\express\_core.py:1210, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1208         if argument == "index":
#    1209             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1210         raise ValueError(err_msg)
#    1211 elif length and len(df_input[argument]) != length:
#    1212     raise ValueError(
#    1213         "All arguments should have the same length. "
#    1214         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1221         )
#    1222     )
#
# ValueError: Value of 'x' is not the name of a column in 'data_frame'. Expected one of ['age ', 'sex    ', 'bmi    ', 'children ', 'smoker ', 'region    ', 'charges'] but received: children

# %%
charges_fig = px.histogram(medical_ins_df,x='charges',marginal='box',color_discrete_sequence=['orange'],title='Charges paid')
charges_fig.update_layout(bargap=0.1)
charges_fig.show()

medical_ins_df.charges.describe()
# Out:
# count     1338.000000
# mean     13270.422265
# std      12110.011237
# min       1121.873900
# 25%       4740.287150
# 50%       9382.033000
# 75%      16639.912515
# max      63770.428010
# Name: charges, dtype: float64

# %%
# analysing string type columns
medical_ins_df.smoker.value_counts()    # get the equivalent integer number defined by this function
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %%
px.histogram(medical_ins_df,x='smoker',color='sex',title='Smoker')

# %%
# age and charges relation using scatterplot through charges

age_charge_rel = px.scatter(medical_ins_df,x='age',y='charges',color='smoker',opacity=0.8,hover_data=['sex'],title='Age vs Charges relation')
age_charge_rel.update_traces(marker_size=5)
age_charge_rel.show()

# %%
bmi_charge_rel = px.scatter(medical_ins_df,x='bmi',y='charges',color='smoker',hover_data='sex')
bmi_charge_rel.update_traces(marker_size=5)
bmi_charge_rel.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 bmi_charge_rel = px.scatter(medical_ins_df,x='bmi',y='charges',color='smoker',hover_data='sex')
#       2 bmi_charge_rel.update_traces(marker_size=5)
#       3 bmi_charge_rel.show()
#
# NameError: name 'px' is not defined

# %%
# correlation coefficients between two numerical datatypes
# medical_ins_df.charges.corr(medical_ins_df.age)
# medical_ins_df.charges.corr(medical_ins_df.bmi)

# for string datatypes
# smoker_val = {'yes':1,'no':0}   # assign them from 0
# smoker_numeric = medical_ins_df.smoker.map(smoker_val)

# medical_ins_df.charges.corr(smoker_numeric)

medical_ins_df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 11
#       1 # correlation coefficients between two numerical datatypes
#       2 # medical_ins_df.charges.corr(medical_ins_df.age)
#       3 # medical_ins_df.charges.corr(medical_ins_df.bmi)
#    (...)
#       8
#       9 # medical_ins_df.charges.corr(smoker_numeric)
# ---> 11 medical_ins_df.corr()
#
# File c:\Users\Harshit Pandit\Desktop\Machine-Learning\.venv\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Harshit Pandit\Desktop\Machine-Learning\.venv\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\Harshit Pandit\Desktop\Machine-Learning\.venv\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File c:\Users\Harshit Pandit\Desktop\Machine-Learning\.venv\Lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'female '
